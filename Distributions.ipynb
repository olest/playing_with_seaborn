# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
df = pd.DataFrame(np.random.normal(0,100,size=(100, 3)), columns=list('XYZ'))
df['Label'] = np.random.choice(['A','B','C'], len(df))
sns.pairplot(df,hue="Label");

# %%
df.head()
sns.violinplot(x=df['Label'],y=df['X'])
